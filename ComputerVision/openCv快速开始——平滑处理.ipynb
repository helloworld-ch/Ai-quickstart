# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
# %matplotlib inline

def img_change_chanels(img):
    return cv2.merge(cv2.split(img)[::-1])

def show(img):
    plt.imshow(img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
def show_sub(images,x,y):
    for i in range(len(images)):
        plt.subplot(x,y,i+1)
        plt.imshow(images[i])
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
cat = cv2.imread("./images/cat.3.jpg")
dog = cv2.imread("./images/dog.3.jpg")
cat = img_change_chanels(cat)
dog = img_change_chanels(dog)

# %%
person = cv2.imread("./images/jiaoyanTest.3.png")
person = img_change_chanels(person)

# %%
show(person)

# %% [markdown]
# ### 均值去噪，方框去噪，均值滤波

# %%
p = cv2.blur(person,(3,3))
show(p)

# %% [markdown]
# ### 中值滤波 将卷积核排序取中位数

# %%
p2 = cv2.medianBlur(person,3)
show(p2)

# %% [markdown]
# ### 高斯滤波 靠近重要位置的权重比例越大

# %%
p3 = cv2.GaussianBlur(person,(5,5),0,0)
show(p3)
