# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
# %matplotlib inline

def img_change_chanels(img):
    return cv2.merge(cv2.split(img)[::-1])

def show(img):
    plt.imshow(img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
def show_sub(images,x,y):
    for i in range(len(images)):
        plt.subplot(x,y,i+1)
        plt.imshow(images[i])
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
# 灰度图显示
def gray_show(img,name = None):
    if name is not None:
        cv2.imshow(name,img)
    else:
        cv2.imshow("img",img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
cat = cv2.imread("./images/cat.3.jpg",0) # 灰度图读取

# %% [markdown]
# ### 直方图绘制
# #### calcHist(images, chanels,mask,hist, min_max)

# %%
hist = cv2.calcHist([cat],[0],None,[256],[0,256])
print(hist.shape)
# Out:
# (256, 1)

# %%
plt.hist(cat.ravel(),256)
plt.show()

# %%
# 三通道

# %%
img = cv2.imread("./images/cat.3.jpg")
show(img)
color = ["b","g","r"]
plt.figure(255)
for step,color in enumerate(color):
    histr = cv2.calcHist([img],[step],None,[256],[0,256])
    plt.plot(hist,c = color)
    plt.show()
