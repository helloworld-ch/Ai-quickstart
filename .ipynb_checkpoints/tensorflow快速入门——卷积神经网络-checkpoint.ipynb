# %%
import tensorflow as tf

# %%
# 设置卷积层

# %%
Conv2_layers = [
    #unit 1
    tf.keras.layers.Conv2D(64,kernel_size=[3,3],padding='same',activation=tf.nn.relu),
    tf.keras.layers.Conv2D(64,kernel_size=[3,3],padding='same',activation=tf.nn.relu),
    tf.keras.layers.MaxPool2D(pool_size=[2,2],strides=2,padding='same'),
    
    #unit 2
    tf.keras.layers.Conv2D(128,kernel_size=[3,3],padding='same',activation=tf.nn.relu),
    tf.keras.layers.Conv2D(128,kernel_size=[3,3],padding='same',activation=tf.nn.relu),
    tf.keras.layers.MaxPool2D(pool_size=[2,2],strides=2,padding='same'),
    
    #unit 3
    tf.keras.layers.Conv2D(256,kernel_size=[3,3],padding='same',activation=tf.nn.relu),
    tf.keras.layers.Conv2D(256,kernel_size=[3,3],padding='same',activation=tf.nn.relu),
    tf.keras.layers.MaxPool2D(pool_size=[2,2],strides=2,padding='same'),
    
    #unit 4
    tf.keras.layers.Conv2D(512,kernel_size=[3,3],padding='same',activation=tf.nn.relu),
    tf.keras.layers.Conv2D(512,kernel_size=[3,3],padding='same',activation=tf.nn.relu),
    tf.keras.layers.MaxPool2D(pool_size=[2,2],strides=2,padding='same'),
    
    #unit 5
    tf.keras.layers.Conv2D(512,kernel_size=[3,3],padding='same',activation=tf.nn.relu),
    tf.keras.layers.Conv2D(512,kernel_size=[3,3],padding='same',activation=tf.nn.relu),
    tf.keras.layers.MaxPool2D(pool_size=[2,2],strides=2,padding='same')
]

# %%
conv_net = tf.keras.Sequential(Conv2_layers)

# %%
conv_net.build([None,32,32,3])

# %%
x = tf.random.uniform([1,32,32,3])

# %%
out = conv_net(x)

# %%
out.shape
# Out:
# TensorShape([1, 1, 1, 512])

# %%
# 搭建线性层网络

# %%
fc_net = tf.keras.Sequential([
    tf.keras.layers.Dense(256,activation=tf.nn.relu),
    tf.keras.layers.Dense(128,activation=tf.nn.relu),
    tf.keras.layers.Dense(100,activation=None)
])

# %%
fc_net.build(input_shape=[None,512])

# %%
b = tf.random.uniform([1,512])

# %%
fc_net(b).shape
# Out:
# TensorShape([1, 100])

# %%
# 设置数据集

# %%
(x,y),(x_test,y_test) = tf.keras.datasets.cifar100.load_data()

# %%
# 数据预处理

# %%
def preprocess(x,y):
    x = tf.cast(x,tf.float32)/255.
    y = tf.cast(y,tf.int32)
    return x,y

# %%
# 设置数据batch

# %%
batchsize = 128
train_db = tf.data.Dataset.from_tensor_slices((x,y))
train_db = train_db.map(preprocess).shuffle(10000).batch(batchsize)
test_db = tf.data.Dataset.from_tensor_slices((x_test,y_test))
test_db = test_db.map(preprocess).batch(batchsize)

# %%
# 取样检查

# %% [markdown]
# sample = next(iter(train_db))

# %%
print(sample[0].shape,sample[1].shape)
# Out:
# (128, 32, 32, 3) (128, 1)

# %%
# 前馈网络

# %%
# 求导参数

# %%
valriable = conv_net.trainable_variables + fc_net.trainable_variables

# %%
optimizer = tf.keras.optimizers.Adam(1e-3)

# %%
for echops in range(10):
    
    for step,(x,y) in enumerate(train_db):
        # 维度变换
        with tf.GradientTape() as tape:
            # 卷积层
            out = conv_net(x)
            #[b,32,32,3] =>[b,1,1,512]
            # Flattern
            out = tf.reshape(out,[-1,512])
            
            # 线性层
            out = fc_net(out)
            
            # 损失函数
            y = tf.reshape(y,[y.shape[0]])
            y_hot = tf.one_hot(y,depth=100)
            
            loss = tf.keras.losses.categorical_crossentropy(y_hot,out,from_logits=True)
            loss = tf.reduce_mean(loss)
            
        grads = tape.gradient(loss,valriable)
        # 优化器
        optimizer.apply_gradients(zip(grads,valriable))
        
        if step % 10 == 0:
            print(step)
            print("loss:",loss)
# Out:
# 0
# loss: tf.Tensor(4.5830846, shape=(), dtype=float32)
# 10
# loss: tf.Tensor
shape=(), dtype=float32)
# 200
# loss: tf.Tensor(2.7837732, shape=(), dtype=float32)
# 210
# loss: tf.Tensor(2.3742285, shape=(), dtype=float32)
# 220
# loss: tf.Tensor(2.3260896, shape=(), dtype=float32)
# 230
# loss: tf.Tensor(2.5027504, shape=(), dtype=float32)
# 240
# loss: tf.Tensor(2.4172115, shape=(), dtype=float32)
# 250
# loss: tf.Tensor(2.501752, shape=(), dtype=float32)
# 260
# loss: tf.Tensor(2.6088371, shape=(), dtype=float32)
# 270
# loss: tf.Tensor(2.2751014, shape=(), dtype=float32)
# 280
# loss: tf.Tensor(2.612042, shape=(), dtype=float32)
# 290
# loss: tf.Tensor(2.2605536, shape=(), dtype=float32)
# 300
# loss: tf.Tensor(2.7587562, shape=(), dtype=float32)
# 310
# loss: tf.Tensor(2.6251965, shape=(), dtype=float32)
# 320
# loss: tf.Tensor(2.4553146, shape=(), dtype=float32)
# 330
# loss: tf.Tensor(2.710116, shape=(), dtype=float32)
# 340
# loss: tf.Tensor(2.615347, shape=(), dtype=float32)
# 350
# loss: tf.Tensor(2.7217522, shape=(), dtype=float32)
# 360
# loss: tf.Tensor(2.5295773, shape=(), dtype=float32)
# 370
# loss: tf.Tensor(2.3083682, shape=(), dtype=float32)
# 380
# loss: tf.Tensor(2.304503, shape=(), dtype=float32)
# 390
# loss: tf.Tensor(2.3697212, shape=(), dtype=float32)
# 0
# loss: tf.Tensor(2.6058893, shape=(), dtype=float32)
# 10
# loss: tf.Tensor(2.3409758, shape=(), dtype=float32)
# 20
# loss: tf.Tensor(2.5522423, shape=(), dtype=float32)
# 30
# loss: tf.Tensor(2.6425571, shape=(), dtype=float32)
# 40
# loss: tf.Tensor(2.4720385, shape=(), dtype=float32)
# 50
# loss: tf.Tensor(2.2557542, shape=(), dtype=float32)
# 60
# loss: tf.Tensor(2.2175102, shape=(), dtype=float32)
# 70
# loss: tf.Tensor(2.4764874, shape=(), dtype=float32)
# 80
# loss: tf.Tensor(2.582382, shape=(), dtype=float32)
# 90
# loss: tf.Tensor(2.5669641, shape=(), dtype=float32)
# 100
# loss: tf.Tensor(2.3055472, shape=(), dtype=float32)
# 110
# loss: tf.Tensor(2.2062817, shape=(), dtype=float32)
# 120
# loss: tf.Tensor(2.6740403, shape=(), dtype=float32)
# 130
# loss: tf.Tensor(2.6654787, shape=(), dtype=float32)
# 140
# loss: tf.Tensor(2.5482354, shape=(), dtype=float32)
# 150
# loss: tf.Tensor(2.4820786, shape=(), dtype=float32)
# 160
# loss: tf.Tensor(2.514979, shape=(), dtype=float32)
# 170
# loss: tf.Tensor(2.3387506, shape=(), dtype=float32)
# 180
# loss: tf.Tensor(2.2493825, shape=(), dtype=float32)
# 190
# loss: tf.Tensor(2.3519921, shape=(), dtype=float32)
# 200
# loss: tf.Tensor(2.4788275, shape=(), dtype=float32)
