# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
# 导入数据

# %%
(x,y),_ = tf.keras.datasets.cifar100.load_data()

# %%
x.shape,y.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1))

# %%
plt.figure()
plt.imshow(x[1])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
print(y[1])
# Out:
# [29]

# %%
plt.figure()
plt.imshow(x[2])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
# 导入数据

# %%
(x_1,y_1),_ = tf.keras.datasets.cifar10.load_data()

# %%
x_1.shape,y_1.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1))

# %%
plt.figure()
plt.imshow(x_1[1])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
plt.figure()
plt.imshow(x_1[2])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
# 导入数据

# %%
(x_2,y_2),_ = tf.keras.datasets.mnist.load_data()

# %%
plt.figure()
plt.imshow(x_2[10]/25)
plt.colorbar()
plt.grid(False)
plt.show()

# %%
print(y_2[10])
# Out:
# 3
